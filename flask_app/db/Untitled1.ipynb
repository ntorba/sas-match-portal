# %%
'{{ form.name(class="teacher-register-input", placeholder="Your Name") }}'=='{{ form.name(class="teacher-register-input", placeholder="Your Name") }}'
# Out:
# True

# %%
import pandas as pd
data_fpath = "file:///home/nick/Downloads/Fall_2020_SAS_Test_data.csv"

df = pd.read_csv(data_fpath)

# %%
for num, i in enumerate(df.columns):
    print(f"{num}) {i} \n")
# Out:
# 0) Timestamp
#
# 1) Email Address
#
# 2) Confirm primary e-mail address
#
# 3) What is your name?
#
# 4) Some school district spam filters prevent us from contacting you. Please provide a second e-mail address.
#
# 5) Please type your secondary e-mail address again
#
# 6) Please provide a phone number which your scientists can call to schedule a session (Optional, but strongly suggested)
#
# 7) What school or group are you associated with? (E.g. "Armstrong middle school" or "Girl scout troop 4156" or "My family")
#
# 8) What City are you located in?
#
# 9) What State are you located in?
#
# 10) If you do NOT live in the USA, what country do you live in?
#
# 11) What time zone are you in?
#
# 12) Monday start time (to the nearest hour, Military format)
#
# 13) Tuesday start time (to the nearest hour, Military format)
#
# 14) Wednesday start time (to the nearest hour, Military format)
#
# 15) Thursday start time (to the nearest hour, Military format)
#
# ...

# %%
df.head()
# Out:
#          Timestamp                  Email Address  \
# 0  8/14/2020 16:23  mdubey@nmschoolforthearts.org
# 1  8/14/2020 18:30         pcinotti@glenridge.org
# 2  8/14/2020 20:24      lauren_pell@ecsonline.org
# 3  8/14/2020 20:28      lauren_pell@ecsonline.org
# 4  8/14/2020 20:31      lauren_pell@ecsonline.org
#
#   Confirm primary e-mail address What is your name?  \
# 0  mdubey@nmschoolforthearts.org        Mohit Dubey
# 1         pcinotti@glenridge.org   Paulette Cinotti
# 2      lauren_pell@ecsonline.org        Lauren Pell
# 3      lauren_pell@ecsonline.org        Lauren Pell
# 4      lauren_pell@ecsonline.org        Lauren Pell
#
#   Some school district spam filters prevent us from contacting you. Please provide a second e-mail address.  \
# 0                                 mdubey@oberlin.edu
# 1                                     pdddmc@aol.com
# 2                             mslaurenpell@gmail.com
# 3                             mslaurenpell@gmail.com
# ...
